# %% [markdown]
# # The classic Recommendation system

# %% [markdown]
# This is a simple recommendation system model.
#
# Here i will implement three kinds of recommendation system:
#
# 1. Popularity based
# 2. content based
# 3. collaborative filtering based
# ----
# I will use [kaggle Book Recomendation](https://www.kaggle.com/datasets/arashnic/book-recommendation-dataset) Dataset to train my model.

# %%
# !pip install kagglehub[pandas-datasets]

# %%
import os
print(os.environ.get('KAGGLE_KEY'))
# Out:
# 7016db84fa30808baaa747e7cb654827

# %%
# Install dependencies as needed:
import kagglehub


# Download latest version
path = kagglehub.dataset_download("arashnic/book-recommendation-dataset")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/arashnic/book-recommendation-dataset?dataset_version_number=3...
# 100%|████████████████████████████████████████████████| 24.3M/24.3M [00:11<00:00, 2.14MB/s]
# Extracting files...
# Path to dataset files: /home/aayushi-raj/.cache/kagglehub/datasets/arashnic/book-recommendation-dataset/versions/3

# %%
import pandas as pd

# %%
books = pd.read_csv(path + '/Books.csv')
user = pd.read_csv(path + '/Users.csv')
ratings = pd.read_csv(path + '/Ratings.csv')
# Out:
# /tmp/ipykernel_27671/2008064841.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books = pd.read_csv(path + '/Books.csv')

# %%
print("books")
print('\n')
print(books.describe())
print("--------")
print("users")
print('\n')
print(user.describe())
print("-------")
print("ratings")
print('\n')
print(ratings.describe())
# Out:
# books
#
#
#               ISBN      Book-Title      Book-Author  Year-Of-Publication  \
# count       271360          271360           271358               271360
# unique      271360          242135           102022                  202
# top     0195153448  Selected Poems  Agatha Christie                 2002
# freq             1              27              632                13903
#
#         Publisher                                        Image-URL-S  \
# count      271358                                             271360
# unique      16807                                             271044
# top     Harlequin  http://images.amazon.com/images/P/042509474X.0...
# freq         7535                                                  2
#
#                                               Image-URL-M  \
# count                                              271360
# unique                                             271044
# top     http://images.amazon.com/images/P/042509474X.0...
# freq                                                    2
#
#                                               Image-URL-L
# count                                              271357
# unique                                             271041
# top     http://images.amazon.com/images/P/006091985X.0...
# freq                                                    2
# --------
# users
#
#
#             User-ID            Age
# count  278858.00000  168096.000000
# mean   139429.50000      34.751434
# std     80499.51502      14.428097
# min         1.00000       0.000000
# 25%     69715.25000      24.000000
# 50%    139429.50000      32.000000
# 75%    209143.75000      44.000000
# max    278858.00000     244.000000
# -------
# ratings
#
#
#             User-ID   Book-Rating
# count  1.149780e+06  1.149780e+06
# mean   1.403864e+05  2.866950e+00
# std    8.056228e+04  3.854184e+00
# min    2.000000e+00  0.000000e+00
# 25%    7.034500e+04  0.000000e+00
# 50%    1.410100e+05  0.000000e+00
# 75%    2.110280e+05  7.000000e+00
# max    2.788540e+05  1.000000e+01

# %% [markdown]
# ## Popularity Based

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 from kagglehub.config import get_kaggle_credentials
# ----> 3 username, _ = get_kaggle_credentials()
#       4 username
#
# TypeError: cannot unpack non-iterable KaggleApiCredentials object
